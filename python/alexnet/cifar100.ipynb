# %%
import torch
import numpy as np
import torchvision
import torch.nn as nn
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import time

# %%
transform = torchvision.transforms.Compose([
    torchvision.transforms.Resize((227, 227)),  
    torchvision.transforms.ToTensor(),       
    torchvision.transforms.Normalize(mean=(0.5,), std=(0.5,)) 
])

train_dataset = torchvision.datasets.CIFAR100(
    root='/home/kami/Documents/datasets/',
    train=True,
    download=True,
    transform=transform
)

train_loader = torch.utils.data.DataLoader(
    train_dataset,
    batch_size=64,
    shuffle=True
)


for images, labels in train_loader:
    print(f"Batch shape: {images.shape}")  
    print(f"Labels shape: {labels.shape}") 
    print(f"Image tensor min: {images.min()}, max: {images.max()}")  
    break
# Out:
# Batch shape: torch.Size([64, 3, 227, 227])
# Labels shape: torch.Size([64])
# Image tensor min: -1.0, max: 1.0

# %%
class AlexNet(nn.Module):
    def __init__(self, num_classes=10, in_channels=1):
        super(AlexNet, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(in_channels, 96, kernel_size=11, stride=4, padding=0),
            nn.BatchNorm2d(96),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 3, stride = 2))
        self.layer2 = nn.Sequential(
            nn.Conv2d(96, 256, kernel_size=5, stride=1, padding=2),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 3, stride = 2))
        self.layer3 = nn.Sequential(
            nn.Conv2d(256, 384, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(384),
            nn.ReLU())
        self.layer4 = nn.Sequential(
            nn.Conv2d(384, 384, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(384),
            nn.ReLU())
        self.layer5 = nn.Sequential(
            nn.Conv2d(384, 256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 3, stride = 2))
        self.fc = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(9216, 4096),
            nn.ReLU())
        self.fc1 = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(4096, 4096),
            nn.ReLU())
        self.fc2= nn.Sequential(
            nn.Linear(4096, num_classes))

    def forward(self, x):
        # print("size 01:" , x.shape)
        out = self.layer1(x)
        # print("size 02:" , out.shape)
        out = self.layer2(out)
        # print("size 03:" , out.shape)
        out = self.layer3(out)
        # print("size 04:" , out.shape)
        out = self.layer4(out)
        # print("size 05:" , out.shape)
        out = self.layer5(out)
        # print("size 06:" , out.shape)
        out = out.reshape(out.size(0), -1)
        # print("size 07:" , out.shape)
        out = self.fc(out)
        # print("size 08:" , out.shape)
        out = self.fc1(out)
        out = self.fc2(out)
        return out

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# device = torch.device('cpu')
model = AlexNet(num_classes=100,in_channels=3).to(device)
criterion = nn.CrossEntropyLoss()  # Combines log softmax and NLL loss
optimizer = optim.Adam(model.parameters(), lr=1e-3)  # Adam with learning rate 1e-3

st = time.time()
# Train for 10 epochs
model.train()
for epoch in range(10):
    batch_index = 0
    for images, labels in train_loader:
        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        outputs = model(images)
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        batch_index += 1
        if batch_index % 100 == 0:
            print(f"Epoch: {epoch} | Batch: {batch_index} | Loss: {loss.item():.4f}")

et = time.time()
print(et-st)
print("Training completed.")
# Out:
# cuda
# Epoch: 0 | Batch: 100 | Loss: 4.4483
# Epoch: 0 | Batch: 200 | Loss: 4.4290
# Epoch: 0 | Batch: 300 | Loss: 4.3505
# Epoch: 0 | Batch: 400 | Loss: 4.4673
# Epoch: 0 | Batch: 500 | Loss: 4.4150
# Epoch: 0 | Batch: 600 | Loss: 4.1768
# Epoch: 0 | Batch: 700 | Loss: 4.1973
# Epoch: 1 | Batch: 100 | Loss: 4.2607
# Epoch: 1 | Batch: 200 | Loss: 4.4698
# Epoch: 1 | Batch: 300 | Loss: 4.1957
# Epoch: 1 | Batch: 400 | Loss: 4.2003
# Epoch: 1 | Batch: 500 | Loss: 4.1726
# Epoch: 1 | Batch: 600 | Loss: 4.1163
# Epoch: 1 | Batch: 700 | Loss: 4.1161
# Epoch: 2 | Batch: 100 | Loss: 4.2273
# Epoch: 2 | Batch: 200 | Loss: 3.9162
# Epoch: 2 | Batch: 300 | Loss: 3.9995
# Epoch: 2 | Batch: 400 | Loss: 4.0265
# Epoch: 2 | Batch: 500 | Loss: 3.9943
# Epoch: 2 | Batch: 600 | Loss: 4.0623
# Epoch: 2 | Batch: 700 | Loss: 4.0696
# Epoch: 3 | Batch: 100 | Loss: 4.2311
# Epoch: 3 | Batch: 200 | Loss: 3.9120
# Epoch: 3 | Batch: 300 | Loss: 3.8767
# Epoch: 3 | Batch: 400 | Loss: 3.4127
# Epoch: 3 | Batch: 500 | Loss: 3.8962
# Epoch: 3 | Batch: 600 | Loss: 3.3047
# Epoch: 3 | Batch: 700 | Loss: 3.8352
# Epoch: 4 | Batch: 100 | Loss: 3.3393
# Epoch: 4 | Batch: 200 | Loss: 3.1445
# Epoch: 4 | Batch: 300 | Loss: 3.6493
# Epoch: 4 | Batch: 400 | Loss: 3.5472
# Epoch: 4 | Batch: 500 | Loss: 3.2524
# Epoch: 4 | Batch: 600 | Loss: 3.3717
# Epoch: 4 | Batch: 700 | Loss: 3.3993
# Epoch: 5 | Batch: 100 | Loss: 3.1015
# Epoch: 5 | Batch: 200 | Loss: 3.2151
# Epoch: 5 | Batch: 300 | Loss: 3.0611
# Epoch: 5 | Batch: 400 | Loss: 3.1278
# Epoch: 5 | Batch: 500 | Loss: 2.9595
# Epoch: 5 | Batch: 600 | Loss: 3.1407
# Epoch: 5 | Batch: 700 | Loss: 2.6858
# Epoch: 6 | Batch: 100 | Loss: 2.8232
# Epoch: 6 | Batch: 200 | Loss: 2.7013
# Epoch: 6 | Batch: 300 | Loss: 3.0885
# Epoch: 6 | Batch: 400 | Loss: 2.8001
# Epoch: 6 | Batch: 500 | Loss: 2.8298
# Epoch: 6 | Batch: 600 | Loss: 2.6193
# Epoch: 6 | Batch: 700 | Loss: 2.4337
# Epoch: 7 | Batch: 100 | Loss: 2.5255
# Epoch: 7 | Batch: 200 | Loss: 2.4961
# Epoch: 7 | Batch: 300 | Loss: 2.4257
# Epoch: 7 | Batch: 400 | Loss: 2.5927
# Epoch: 7 | Batch: 500 | Loss: 2.5827
# Epoch: 7 | Batch: 600 | Loss: 2.7193
# Epoch: 7 | Batch: 700 | Loss: 2.9525
# Epoch: 8 | Batch: 100 | Loss: 2.3170
# Epoch: 8 | Batch: 200 | Loss: 2.4161
# Epoch: 8 | Batch: 300 | Loss: 2.4971
# Epoch: 8 | Batch: 400 | Loss: 2.9997
# Epoch: 8 | Batch: 500 | Loss: 2.5790
# Epoch: 8 | Batch: 600 | Loss: 2.2364
# Epoch: 8 | Batch: 700 | Loss: 2.3699
# Epoch: 9 | Batch: 100 | Loss: 2.5421
# Epoch: 9 | Batch: 200 | Loss: 2.6372
# Epoch: 9 | Batch: 300 | Loss: 2.3271
# Epoch: 9 | Batch: 400 | Loss: 2.4466
# Epoch: 9 | Batch: 500 | Loss: 2.4034
# Epoch: 9 | Batch: 600 | Loss: 2.3808
# Epoch: 9 | Batch: 700 | Loss: 2.3818
# 337.04542565345764
# Training completed.
