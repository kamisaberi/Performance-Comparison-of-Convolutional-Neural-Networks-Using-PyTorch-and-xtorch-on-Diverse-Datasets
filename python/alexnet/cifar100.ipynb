# %%
import torch
import numpy as np
import torchvision
import torch.nn as nn
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import time

# %%
transform = torchvision.transforms.Compose([
    torchvision.transforms.Resize((227, 227)),  
    torchvision.transforms.ToTensor(),       
    torchvision.transforms.Normalize(mean=(0.5,), std=(0.5,)) 
])

train_dataset = torchvision.datasets.CIFAR100(
    root='/home/kami/Documents/datasets/',
    train=True,
    download=True,
    transform=transform
)

train_loader = torch.utils.data.DataLoader(
    train_dataset,
    batch_size=64,
    shuffle=True
)


for images, labels in train_loader:
    print(f"Batch shape: {images.shape}")  
    print(f"Labels shape: {labels.shape}") 
    print(f"Image tensor min: {images.min()}, max: {images.max()}")  
    break
# Out:
# Batch shape: torch.Size([64, 3, 227, 227])
# Labels shape: torch.Size([64])
# Image tensor min: -1.0, max: 1.0

# %%
class AlexNet(nn.Module):
    def __init__(self, num_classes=10, in_channels=1):
        super(AlexNet, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(in_channels, 96, kernel_size=11, stride=4, padding=0),
            nn.BatchNorm2d(96),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 3, stride = 2))
        self.layer2 = nn.Sequential(
            nn.Conv2d(96, 256, kernel_size=5, stride=1, padding=2),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 3, stride = 2))
        self.layer3 = nn.Sequential(
            nn.Conv2d(256, 384, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(384),
            nn.ReLU())
        self.layer4 = nn.Sequential(
            nn.Conv2d(384, 384, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(384),
            nn.ReLU())
        self.layer5 = nn.Sequential(
            nn.Conv2d(384, 256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 3, stride = 2))
        self.fc = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(9216, 4096),
            nn.ReLU())
        self.fc1 = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(4096, 4096),
            nn.ReLU())
        self.fc2= nn.Sequential(
            nn.Linear(4096, num_classes))

    def forward(self, x):
        # print("size 01:" , x.shape)
        out = self.layer1(x)
        # print("size 02:" , out.shape)
        out = self.layer2(out)
        # print("size 03:" , out.shape)
        out = self.layer3(out)
        # print("size 04:" , out.shape)
        out = self.layer4(out)
        # print("size 05:" , out.shape)
        out = self.layer5(out)
        # print("size 06:" , out.shape)
        out = out.reshape(out.size(0), -1)
        # print("size 07:" , out.shape)
        out = self.fc(out)
        # print("size 08:" , out.shape)
        out = self.fc1(out)
        out = self.fc2(out)
        return out

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# device = torch.device('cpu')
model = AlexNet(num_classes=100,in_channels=3).to(device)
criterion = nn.CrossEntropyLoss()  # Combines log softmax and NLL loss
optimizer = optim.Adam(model.parameters(), lr=1e-3)  # Adam with learning rate 1e-3

st = time.time()
# Train for 10 epochs
model.train()
for epoch in range(10):
    batch_index = 0
    for images, labels in train_loader:
        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        outputs = model(images)
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        batch_index += 1
        if batch_index % 100 == 0:
            print(f"Epoch: {epoch} | Batch: {batch_index} | Loss: {loss.item():.4f}")

et = time.time()
print(et-st)
print("Training completed.")
# Out:
# cuda
# Epoch: 0 | Batch: 100 | Loss: 4.6371
# Epoch: 0 | Batch: 200 | Loss: 4.3485
# Epoch: 0 | Batch: 300 | Loss: 4.1785
# Epoch: 0 | Batch: 400 | Loss: 4.3661
# Epoch: 0 | Batch: 500 | Loss: 4.2344
# Epoch: 0 | Batch: 600 | Loss: 4.1469
# Epoch: 0 | Batch: 700 | Loss: 4.4167
# Epoch: 1 | Batch: 100 | Loss: 4.2883
# Epoch: 1 | Batch: 200 | Loss: 4.3310
# Epoch: 1 | Batch: 300 | Loss: 4.0614
# Epoch: 1 | Batch: 400 | Loss: 4.2308
# Epoch: 1 | Batch: 500 | Loss: 4.1703
# Epoch: 1 | Batch: 600 | Loss: 4.1578
# Epoch: 1 | Batch: 700 | Loss: 4.0333
# Epoch: 2 | Batch: 100 | Loss: 3.8720
# Epoch: 2 | Batch: 200 | Loss: 3.9013
# Epoch: 2 | Batch: 300 | Loss: 4.0725
# Epoch: 2 | Batch: 400 | Loss: 4.1757
# Epoch: 2 | Batch: 500 | Loss: 3.9261
# Epoch: 2 | Batch: 600 | Loss: 4.0726
# Epoch: 2 | Batch: 700 | Loss: 4.0979
# Epoch: 3 | Batch: 100 | Loss: 3.9843
# Epoch: 3 | Batch: 200 | Loss: 3.8809
# Epoch: 3 | Batch: 300 | Loss: 3.8666
# Epoch: 3 | Batch: 400 | Loss: 3.5717
# Epoch: 3 | Batch: 500 | Loss: 3.8033
# Epoch: 3 | Batch: 600 | Loss: 3.6748
# Epoch: 3 | Batch: 700 | Loss: 3.6854
# Epoch: 4 | Batch: 100 | Loss: 3.6737
# Epoch: 4 | Batch: 200 | Loss: 3.4953
# Epoch: 4 | Batch: 300 | Loss: 3.7427
# Epoch: 4 | Batch: 400 | Loss: 3.4463
# Epoch: 4 | Batch: 500 | Loss: 3.6584
# Epoch: 4 | Batch: 600 | Loss: 3.3400
# Epoch: 4 | Batch: 700 | Loss: 3.1780
# Epoch: 5 | Batch: 100 | Loss: 3.4442
# Epoch: 5 | Batch: 200 | Loss: 3.0281
# Epoch: 5 | Batch: 300 | Loss: 3.3741
# Epoch: 5 | Batch: 400 | Loss: 3.3476
# Epoch: 5 | Batch: 500 | Loss: 3.1690
# Epoch: 5 | Batch: 600 | Loss: 3.3065
# Epoch: 5 | Batch: 700 | Loss: 2.8731
# Epoch: 6 | Batch: 100 | Loss: 2.9309
# Epoch: 6 | Batch: 200 | Loss: 3.0772
# Epoch: 6 | Batch: 300 | Loss: 3.1376
# Epoch: 6 | Batch: 400 | Loss: 2.8195
# Epoch: 6 | Batch: 500 | Loss: 2.9356
# Epoch: 6 | Batch: 600 | Loss: 3.1470
# Epoch: 6 | Batch: 700 | Loss: 2.7041
# Epoch: 7 | Batch: 100 | Loss: 2.7654
# Epoch: 7 | Batch: 200 | Loss: 2.6137
# Epoch: 7 | Batch: 300 | Loss: 2.6234
# Epoch: 7 | Batch: 400 | Loss: 2.8492
# Epoch: 7 | Batch: 500 | Loss: 2.9060
# Epoch: 7 | Batch: 600 | Loss: 2.9875
# Epoch: 7 | Batch: 700 | Loss: 2.7740
# Epoch: 8 | Batch: 100 | Loss: 2.4315
# Epoch: 8 | Batch: 200 | Loss: 2.8606
# Epoch: 8 | Batch: 300 | Loss: 2.6480
# Epoch: 8 | Batch: 400 | Loss: 2.5657
# Epoch: 8 | Batch: 500 | Loss: 2.7634
# Epoch: 8 | Batch: 600 | Loss: 2.6594
# Epoch: 8 | Batch: 700 | Loss: 2.7325
# Epoch: 9 | Batch: 100 | Loss: 2.4917
# Epoch: 9 | Batch: 200 | Loss: 2.3202
# Epoch: 9 | Batch: 300 | Loss: 2.3288
# Epoch: 9 | Batch: 400 | Loss: 2.2127
# Epoch: 9 | Batch: 500 | Loss: 2.3717
# Epoch: 9 | Batch: 600 | Loss: 2.2169
# Epoch: 9 | Batch: 700 | Loss: 2.5568
# 333.8808603286743
# Training completed.
