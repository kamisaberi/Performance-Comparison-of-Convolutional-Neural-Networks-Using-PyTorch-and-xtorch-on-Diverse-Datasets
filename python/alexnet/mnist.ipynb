# %%
import torch
import numpy as np
import torchvision
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import time

# %%
transform = torchvision.transforms.Compose([
    torchvision.transforms.Resize((227, 227)),  # Resize images to 32x32 pixels
    torchvision.transforms.ToTensor(),        # Convert images to PyTorch tensors
    torchvision.transforms.Normalize(mean=(0.5,), std=(0.5,))  # Normalize with mean=0.5, std=0.5
])

train_dataset = torchvision.datasets.MNIST(
    root='/home/kami/Documents/datasets/',
    train=True,
    download=False,
    transform=transform
)

train_loader = torch.utils.data.DataLoader(
    train_dataset,
    batch_size=64,
    shuffle=True
)

# Example: Iterate through one batch to verify the data
for images, labels in train_loader:
    print(f"Batch shape: {images.shape}")  # Should be [64, 1, 32, 32] (batch, channels, height, width)
    print(f"Labels shape: {labels.shape}")  # Should be [64]
    print(f"Image tensor min: {images.min()}, max: {images.max()}")  # Check normalization
    break  # Only print the first batch
# Out:
# Batch shape: torch.Size([64, 1, 227, 227])
# Labels shape: torch.Size([64])
# Image tensor min: -1.0, max: 1.0

# %%
class AlexNet(nn.Module):
    def __init__(self, num_classes=10, in_channels=1):
        super(AlexNet, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(in_channels, 96, kernel_size=11, stride=4, padding=0),
            nn.BatchNorm2d(96),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 3, stride = 2))
        self.layer2 = nn.Sequential(
            nn.Conv2d(96, 256, kernel_size=5, stride=1, padding=2),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 3, stride = 2))
        self.layer3 = nn.Sequential(
            nn.Conv2d(256, 384, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(384),
            nn.ReLU())
        self.layer4 = nn.Sequential(
            nn.Conv2d(384, 384, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(384),
            nn.ReLU())
        self.layer5 = nn.Sequential(
            nn.Conv2d(384, 256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 3, stride = 2))
        self.fc = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(9216, 4096),
            nn.ReLU())
        self.fc1 = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(4096, 4096),
            nn.ReLU())
        self.fc2= nn.Sequential(
            nn.Linear(4096, num_classes))

    def forward(self, x):
        # print("size 01:" , x.shape)
        out = self.layer1(x)
        # print("size 02:" , out.shape)
        out = self.layer2(out)
        # print("size 03:" , out.shape)
        out = self.layer3(out)
        # print("size 04:" , out.shape)
        out = self.layer4(out)
        # print("size 05:" , out.shape)
        out = self.layer5(out)
        # print("size 06:" , out.shape)
        out = out.reshape(out.size(0), -1)
        # print("size 07:" , out.shape)
        out = self.fc(out)
        # print("size 08:" , out.shape)
        out = self.fc1(out)
        out = self.fc2(out)
        return out

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# device = torch.device('cpu')
model = AlexNet(num_classes=10,in_channels=1).to(device)
criterion = nn.CrossEntropyLoss()  # Combines log softmax and NLL loss
optimizer = optim.Adam(model.parameters(), lr=1e-3)  # Adam with learning rate 1e-3

st = time.time()
# Train for 10 epochs
model.train()
for epoch in range(10):
    batch_index = 0
    for images, labels in train_loader:
        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        outputs = model(images)
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        batch_index += 1
        if batch_index % 100 == 0:
            print(f"Epoch: {epoch} | Batch: {batch_index} | Loss: {loss.item():.4f}")

et = time.time()
print(et-st)
print("Training completed.")
# Out:
# cuda
# Epoch: 0 | Batch: 100 | Loss: 1.0208
# Epoch: 0 | Batch: 200 | Loss: 0.8811
# Epoch: 0 | Batch: 300 | Loss: 0.9561
# Epoch: 0 | Batch: 400 | Loss: 0.5896
# Epoch: 0 | Batch: 500 | Loss: 0.5332
# Epoch: 0 | Batch: 600 | Loss: 0.5987
# Epoch: 0 | Batch: 700 | Loss: 0.4080
# Epoch: 0 | Batch: 800 | Loss: 0.4527
# Epoch: 0 | Batch: 900 | Loss: 0.4771
# Epoch: 1 | Batch: 100 | Loss: 0.4868
# Epoch: 1 | Batch: 200 | Loss: 0.2644
# Epoch: 1 | Batch: 300 | Loss: 0.4680
# Epoch: 1 | Batch: 400 | Loss: 0.3185
# Epoch: 1 | Batch: 500 | Loss: 0.4427
# Epoch: 1 | Batch: 600 | Loss: 0.3968
# Epoch: 1 | Batch: 700 | Loss: 0.2681
# Epoch: 1 | Batch: 800 | Loss: 0.3144
# Epoch: 1 | Batch: 900 | Loss: 0.5081
# Epoch: 2 | Batch: 100 | Loss: 0.2610
# Epoch: 2 | Batch: 200 | Loss: 0.2670
# Epoch: 2 | Batch: 300 | Loss: 0.4237
# Epoch: 2 | Batch: 400 | Loss: 0.2806
# Epoch: 2 | Batch: 500 | Loss: 0.3947
# Epoch: 2 | Batch: 600 | Loss: 0.3635
# Epoch: 2 | Batch: 700 | Loss: 0.5983
# Epoch: 2 | Batch: 800 | Loss: 0.2259
# Epoch: 2 | Batch: 900 | Loss: 0.0876
# Epoch: 3 | Batch: 100 | Loss: 0.1894
# Epoch: 3 | Batch: 200 | Loss: 0.2578
# Epoch: 3 | Batch: 300 | Loss: 0.0665
# Epoch: 3 | Batch: 400 | Loss: 0.1472
# Epoch: 3 | Batch: 500 | Loss: 0.1126
# Epoch: 3 | Batch: 600 | Loss: 0.1753
# Epoch: 3 | Batch: 700 | Loss: 0.1402
# Epoch: 3 | Batch: 800 | Loss: 0.1847
# Epoch: 3 | Batch: 900 | Loss: 0.2010
# Epoch: 4 | Batch: 100 | Loss: 0.2472
# Epoch: 4 | Batch: 200 | Loss: 0.0979
# Epoch: 4 | Batch: 300 | Loss: 0.2003
# Epoch: 4 | Batch: 400 | Loss: 0.1848
# Epoch: 4 | Batch: 500 | Loss: 0.0840
# Epoch: 4 | Batch: 600 | Loss: 0.1553
# Epoch: 4 | Batch: 700 | Loss: 0.6166
# Epoch: 4 | Batch: 800 | Loss: 0.1525
# Epoch: 4 | Batch: 900 | Loss: 0.1066
# Epoch: 5 | Batch: 100 | Loss: 0.0640
# Epoch: 5 | Batch: 200 | Loss: 0.1322
# Epoch: 5 | Batch: 300 | Loss: 0.0575
# Epoch: 5 | Batch: 400 | Loss: 0.2227
# Epoch: 5 | Batch: 500 | Loss: 0.1206
# Epoch: 5 | Batch: 600 | Loss: 0.2357
# Epoch: 5 | Batch: 700 | Loss: 0.0472
# Epoch: 5 | Batch: 800 | Loss: 0.1333
# Epoch: 5 | Batch: 900 | Loss: 0.1037
# Epoch: 6 | Batch: 100 | Loss: 0.0658
# Epoch: 6 | Batch: 200 | Loss: 0.0411
# Epoch: 6 | Batch: 300 | Loss: 0.0716
# Epoch: 6 | Batch: 400 | Loss: 0.0498
# Epoch: 6 | Batch: 500 | Loss: 0.0139
# Epoch: 6 | Batch: 600 | Loss: 0.0872
# Epoch: 6 | Batch: 700 | Loss: 0.1685
# Epoch: 6 | Batch: 800 | Loss: 0.0638
# Epoch: 6 | Batch: 900 | Loss: 0.1991
# Epoch: 7 | Batch: 100 | Loss: 0.2469
# Epoch: 7 | Batch: 200 | Loss: 0.1559
# Epoch: 7 | Batch: 300 | Loss: 0.0115
# Epoch: 7 | Batch: 400 | Loss: 0.0379
# Epoch: 7 | Batch: 500 | Loss: 0.0513
# Epoch: 7 | Batch: 600 | Loss: 0.1297
# Epoch: 7 | Batch: 700 | Loss: 0.0176
# Epoch: 7 | Batch: 800 | Loss: 0.0365
# Epoch: 7 | Batch: 900 | Loss: 0.0028
# Epoch: 8 | Batch: 100 | Loss: 0.0676
# Epoch: 8 | Batch: 200 | Loss: 0.2143
# Epoch: 8 | Batch: 300 | Loss: 0.0716
# Epoch: 8 | Batch: 400 | Loss: 0.1495
# Epoch: 8 | Batch: 500 | Loss: 0.0703
# Epoch: 8 | Batch: 600 | Loss: 0.0695
# Epoch: 8 | Batch: 700 | Loss: 0.0178
# Epoch: 8 | Batch: 800 | Loss: 0.0243
# Epoch: 8 | Batch: 900 | Loss: 0.0117
# Epoch: 9 | Batch: 100 | Loss: 0.0303
# Epoch: 9 | Batch: 200 | Loss: 0.0564
# Epoch: 9 | Batch: 300 | Loss: 0.2065
# Epoch: 9 | Batch: 400 | Loss: 0.0018
# Epoch: 9 | Batch: 500 | Loss: 0.0231
# Epoch: 9 | Batch: 600 | Loss: 0.2102
# Epoch: 9 | Batch: 700 | Loss: 0.0196
# Epoch: 9 | Batch: 800 | Loss: 0.0150
# Epoch: 9 | Batch: 900 | Loss: 0.0148
# 274.99227690696716
# Training completed.
