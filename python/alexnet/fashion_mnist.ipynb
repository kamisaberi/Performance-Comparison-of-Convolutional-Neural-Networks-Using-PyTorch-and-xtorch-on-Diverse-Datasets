# %%
import torch
import numpy as np
import torchvision
import torch.nn as nn
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import time

# %%
transform = torchvision.transforms.Compose([
    torchvision.transforms.Resize((227, 227)),  # Resize images to 32x32 pixels
    torchvision.transforms.ToTensor(),        # Convert images to PyTorch tensors
    torchvision.transforms.Normalize(mean=(0.5,), std=(0.5,))  # Normalize with mean=0.5, std=0.5
])

train_dataset = torchvision.datasets.FashionMNIST(
    root='/home/kami/Documents/datasets/',
    train=True,
    download=False,
    transform=transform
)

train_loader = torch.utils.data.DataLoader(
    train_dataset,
    batch_size=64,
    shuffle=True
)

for images, labels in train_loader:
    print(f"Batch shape: {images.shape}")  # Should be [64, 1, 32, 32] (batch, channels, height, width)
    print(f"Labels shape: {labels.shape}")  # Should be [64]
    print(f"Image tensor min: {images.min()}, max: {images.max()}")  # Check normalization
    break  # Only print the first batch
# Out:
# Batch shape: torch.Size([64, 1, 227, 227])
# Labels shape: torch.Size([64])
# Image tensor min: -1.0, max: 1.0

# %%
class AlexNet(nn.Module):
    def __init__(self, num_classes=10, in_channels=1):
        super(AlexNet, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(in_channels, 96, kernel_size=11, stride=4, padding=0),
            nn.BatchNorm2d(96),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 3, stride = 2))
        self.layer2 = nn.Sequential(
            nn.Conv2d(96, 256, kernel_size=5, stride=1, padding=2),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 3, stride = 2))
        self.layer3 = nn.Sequential(
            nn.Conv2d(256, 384, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(384),
            nn.ReLU())
        self.layer4 = nn.Sequential(
            nn.Conv2d(384, 384, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(384),
            nn.ReLU())
        self.layer5 = nn.Sequential(
            nn.Conv2d(384, 256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 3, stride = 2))
        self.fc = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(9216, 4096),
            nn.ReLU())
        self.fc1 = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(4096, 4096),
            nn.ReLU())
        self.fc2= nn.Sequential(
            nn.Linear(4096, num_classes))

    def forward(self, x):
        # print("size 01:" , x.shape)
        out = self.layer1(x)
        # print("size 02:" , out.shape)
        out = self.layer2(out)
        # print("size 03:" , out.shape)
        out = self.layer3(out)
        # print("size 04:" , out.shape)
        out = self.layer4(out)
        # print("size 05:" , out.shape)
        out = self.layer5(out)
        # print("size 06:" , out.shape)
        out = out.reshape(out.size(0), -1)
        # print("size 07:" , out.shape)
        out = self.fc(out)
        # print("size 08:" , out.shape)
        out = self.fc1(out)
        out = self.fc2(out)
        return out

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# device = torch.device('cpu')
model = AlexNet(num_classes=10,in_channels=1).to(device)
criterion = nn.CrossEntropyLoss()  # Combines log softmax and NLL loss
optimizer = optim.Adam(model.parameters(), lr=1e-3)  # Adam with learning rate 1e-3

st = time.time()
# Train for 10 epochs
model.train()
for epoch in range(10):
    batch_index = 0
    for images, labels in train_loader:
        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        outputs = model(images)
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        batch_index += 1
        if batch_index % 100 == 0:
            print(f"Epoch: {epoch} | Batch: {batch_index} | Loss: {loss.item():.4f}")

et = time.time()
print(et-st)
print("Training completed.")
# Out:
# cuda
# Epoch: 0 | Batch: 100 | Loss: 1.0200
# Epoch: 0 | Batch: 200 | Loss: 0.8561
# Epoch: 0 | Batch: 300 | Loss: 0.9156
# Epoch: 0 | Batch: 400 | Loss: 0.5951
# Epoch: 0 | Batch: 500 | Loss: 0.8708
# Epoch: 0 | Batch: 600 | Loss: 0.9112
# Epoch: 0 | Batch: 700 | Loss: 0.7445
# Epoch: 0 | Batch: 800 | Loss: 0.5182
# Epoch: 0 | Batch: 900 | Loss: 0.8254
# Epoch: 1 | Batch: 100 | Loss: 0.7246
# Epoch: 1 | Batch: 200 | Loss: 0.7007
# Epoch: 1 | Batch: 300 | Loss: 0.5655
# Epoch: 1 | Batch: 400 | Loss: 0.6419
# Epoch: 1 | Batch: 500 | Loss: 0.8622
# Epoch: 1 | Batch: 600 | Loss: 0.7547
# Epoch: 1 | Batch: 700 | Loss: 0.5966
# Epoch: 1 | Batch: 800 | Loss: 0.5095
# Epoch: 1 | Batch: 900 | Loss: 0.6062
# Epoch: 2 | Batch: 100 | Loss: 0.5175
# Epoch: 2 | Batch: 200 | Loss: 0.6220
# Epoch: 2 | Batch: 300 | Loss: 0.5192
# Epoch: 2 | Batch: 400 | Loss: 0.8472
# Epoch: 2 | Batch: 500 | Loss: 0.4188
# Epoch: 2 | Batch: 600 | Loss: 0.8048
# Epoch: 2 | Batch: 700 | Loss: 0.4414
# Epoch: 2 | Batch: 800 | Loss: 0.3582
# Epoch: 2 | Batch: 900 | Loss: 0.5788
# Epoch: 3 | Batch: 100 | Loss: 0.5063
# Epoch: 3 | Batch: 200 | Loss: 0.6472
# Epoch: 3 | Batch: 300 | Loss: 0.6757
# Epoch: 3 | Batch: 400 | Loss: 0.5603
# Epoch: 3 | Batch: 500 | Loss: 0.5791
# Epoch: 3 | Batch: 600 | Loss: 0.4175
# Epoch: 3 | Batch: 700 | Loss: 0.7478
# Epoch: 3 | Batch: 800 | Loss: 0.5459
# Epoch: 3 | Batch: 900 | Loss: 0.6934
# Epoch: 4 | Batch: 100 | Loss: 0.4789
# Epoch: 4 | Batch: 200 | Loss: 0.5613
# Epoch: 4 | Batch: 300 | Loss: 0.4978
# Epoch: 4 | Batch: 400 | Loss: 0.4368
# Epoch: 4 | Batch: 500 | Loss: 0.6643
# Epoch: 4 | Batch: 600 | Loss: 0.4417
# Epoch: 4 | Batch: 700 | Loss: 0.4261
# Epoch: 4 | Batch: 800 | Loss: 0.4119
# Epoch: 4 | Batch: 900 | Loss: 0.4365
# Epoch: 5 | Batch: 100 | Loss: 0.4809
# Epoch: 5 | Batch: 200 | Loss: 0.4901
# Epoch: 5 | Batch: 300 | Loss: 0.4378
# Epoch: 5 | Batch: 400 | Loss: 0.2227
# Epoch: 5 | Batch: 500 | Loss: 0.4898
# Epoch: 5 | Batch: 600 | Loss: 0.6056
# Epoch: 5 | Batch: 700 | Loss: 0.3871
# Epoch: 5 | Batch: 800 | Loss: 0.3672
# Epoch: 5 | Batch: 900 | Loss: 0.2693
# Epoch: 6 | Batch: 100 | Loss: 0.4856
# Epoch: 6 | Batch: 200 | Loss: 0.4488
# Epoch: 6 | Batch: 300 | Loss: 0.3585
# Epoch: 6 | Batch: 400 | Loss: 0.4317
# Epoch: 6 | Batch: 500 | Loss: 0.2287
# Epoch: 6 | Batch: 600 | Loss: 0.2962
# Epoch: 6 | Batch: 700 | Loss: 0.1927
# Epoch: 6 | Batch: 800 | Loss: 0.3096
# Epoch: 6 | Batch: 900 | Loss: 0.3280
# Epoch: 7 | Batch: 100 | Loss: 0.3588
# Epoch: 7 | Batch: 200 | Loss: 0.2647
# Epoch: 7 | Batch: 300 | Loss: 0.2156
# Epoch: 7 | Batch: 400 | Loss: 0.2607
# Epoch: 7 | Batch: 500 | Loss: 0.4044
# Epoch: 7 | Batch: 600 | Loss: 0.1726
# Epoch: 7 | Batch: 700 | Loss: 0.3293
# Epoch: 7 | Batch: 800 | Loss: 0.4693
# Epoch: 7 | Batch: 900 | Loss: 0.3132
# Epoch: 8 | Batch: 100 | Loss: 0.3788
# Epoch: 8 | Batch: 200 | Loss: 0.3232
# Epoch: 8 | Batch: 300 | Loss: 0.6215
# Epoch: 8 | Batch: 400 | Loss: 0.3144
# Epoch: 8 | Batch: 500 | Loss: 0.2264
# Epoch: 8 | Batch: 600 | Loss: 0.2445
# Epoch: 8 | Batch: 700 | Loss: 0.3421
# Epoch: 8 | Batch: 800 | Loss: 0.2725
# Epoch: 8 | Batch: 900 | Loss: 0.4132
# Epoch: 9 | Batch: 100 | Loss: 0.2588
# Epoch: 9 | Batch: 200 | Loss: 0.4371
# Epoch: 9 | Batch: 300 | Loss: 0.3072
# Epoch: 9 | Batch: 400 | Loss: 0.1812
# Epoch: 9 | Batch: 500 | Loss: 0.1010
# Epoch: 9 | Batch: 600 | Loss: 0.2015
# Epoch: 9 | Batch: 700 | Loss: 0.3155
# Epoch: 9 | Batch: 800 | Loss: 0.3487
# Epoch: 9 | Batch: 900 | Loss: 0.3044
# 273.77002453804016
# Training completed.
