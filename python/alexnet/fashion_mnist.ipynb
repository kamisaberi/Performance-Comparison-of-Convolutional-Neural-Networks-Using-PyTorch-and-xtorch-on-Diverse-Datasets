# %%
import torch
import numpy as np
import torchvision
import torch.nn as nn
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import time

# %%
transform = torchvision.transforms.Compose([
    torchvision.transforms.Resize((227, 227)),  # Resize images to 32x32 pixels
    torchvision.transforms.ToTensor(),        # Convert images to PyTorch tensors
    torchvision.transforms.Normalize(mean=(0.5,), std=(0.5,))  # Normalize with mean=0.5, std=0.5
])

train_dataset = torchvision.datasets.FashionMNIST(
    root='/home/kami/Documents/datasets/',
    train=True,
    download=False,
    transform=transform
)

train_loader = torch.utils.data.DataLoader(
    train_dataset,
    batch_size=64,
    shuffle=True
)

for images, labels in train_loader:
    print(f"Batch shape: {images.shape}")  # Should be [64, 1, 32, 32] (batch, channels, height, width)
    print(f"Labels shape: {labels.shape}")  # Should be [64]
    print(f"Image tensor min: {images.min()}, max: {images.max()}")  # Check normalization
    break  # Only print the first batch
# Out:
# Batch shape: torch.Size([64, 1, 32, 32])
# Labels shape: torch.Size([64])
# Image tensor min: -1.0, max: 1.0

# %%
class AlexNet(nn.Module):
    def __init__(self, num_classes=10, in_channels=1):
        super(AlexNet, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(in_channels, 96, kernel_size=11, stride=4, padding=0),
            nn.BatchNorm2d(96),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 3, stride = 2))
        self.layer2 = nn.Sequential(
            nn.Conv2d(96, 256, kernel_size=5, stride=1, padding=2),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 3, stride = 2))
        self.layer3 = nn.Sequential(
            nn.Conv2d(256, 384, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(384),
            nn.ReLU())
        self.layer4 = nn.Sequential(
            nn.Conv2d(384, 384, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(384),
            nn.ReLU())
        self.layer5 = nn.Sequential(
            nn.Conv2d(384, 256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 3, stride = 2))
        self.fc = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(9216, 4096),
            nn.ReLU())
        self.fc1 = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(4096, 4096),
            nn.ReLU())
        self.fc2= nn.Sequential(
            nn.Linear(4096, num_classes))

    def forward(self, x):
        # print("size 01:" , x.shape)
        out = self.layer1(x)
        # print("size 02:" , out.shape)
        out = self.layer2(out)
        # print("size 03:" , out.shape)
        out = self.layer3(out)
        # print("size 04:" , out.shape)
        out = self.layer4(out)
        # print("size 05:" , out.shape)
        out = self.layer5(out)
        # print("size 06:" , out.shape)
        out = out.reshape(out.size(0), -1)
        # print("size 07:" , out.shape)
        out = self.fc(out)
        # print("size 08:" , out.shape)
        out = self.fc1(out)
        out = self.fc2(out)
        return out

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# device = torch.device('cpu')
model = AlexNet(num_classes=10,in_channels=1).to(device)
criterion = nn.CrossEntropyLoss()  # Combines log softmax and NLL loss
optimizer = optim.Adam(model.parameters(), lr=1e-3)  # Adam with learning rate 1e-3

st = time.time()
# Train for 10 epochs
model.train()
for epoch in range(10):
    batch_index = 0
    for images, labels in train_loader:
        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        outputs = model(images)
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        batch_index += 1
        if batch_index % 100 == 0:
            print(f"Epoch: {epoch} | Batch: {batch_index} | Loss: {loss.item():.4f}")

et = time.time()
print(et-st)
print("Training completed.")
# Out:
# cuda
# Epoch: 0 | Batch: 100 | Loss: 0.5713
# Epoch: 0 | Batch: 200 | Loss: 0.1703
# Epoch: 0 | Batch: 300 | Loss: 0.2236
# Epoch: 0 | Batch: 400 | Loss: 0.1021
# Epoch: 0 | Batch: 500 | Loss: 0.1208
# Epoch: 0 | Batch: 600 | Loss: 0.1039
# Epoch: 0 | Batch: 700 | Loss: 0.0659
# Epoch: 0 | Batch: 800 | Loss: 0.0580
# Epoch: 0 | Batch: 900 | Loss: 0.1150
# Epoch: 1 | Batch: 100 | Loss: 0.1125
# Epoch: 1 | Batch: 200 | Loss: 0.0124
# Epoch: 1 | Batch: 300 | Loss: 0.0465
# Epoch: 1 | Batch: 400 | Loss: 0.0505
# Epoch: 1 | Batch: 500 | Loss: 0.0658
# Epoch: 1 | Batch: 600 | Loss: 0.0166
# Epoch: 1 | Batch: 700 | Loss: 0.0126
# Epoch: 1 | Batch: 800 | Loss: 0.0658
# Epoch: 1 | Batch: 900 | Loss: 0.0819
# Epoch: 2 | Batch: 100 | Loss: 0.0133
# Epoch: 2 | Batch: 200 | Loss: 0.0153
# Epoch: 2 | Batch: 300 | Loss: 0.0155
# Epoch: 2 | Batch: 400 | Loss: 0.0155
# Epoch: 2 | Batch: 500 | Loss: 0.0656
# Epoch: 2 | Batch: 600 | Loss: 0.1223
# Epoch: 2 | Batch: 700 | Loss: 0.0333
# Epoch: 2 | Batch: 800 | Loss: 0.1392
# Epoch: 2 | Batch: 900 | Loss: 0.0655
# Epoch: 3 | Batch: 100 | Loss: 0.0662
# Epoch: 3 | Batch: 200 | Loss: 0.1241
# Epoch: 3 | Batch: 300 | Loss: 0.0058
# Epoch: 3 | Batch: 400 | Loss: 0.0105
# Epoch: 3 | Batch: 500 | Loss: 0.1957
# Epoch: 3 | Batch: 600 | Loss: 0.0273
# Epoch: 3 | Batch: 700 | Loss: 0.0169
# Epoch: 3 | Batch: 800 | Loss: 0.0827
# Epoch: 3 | Batch: 900 | Loss: 0.2082
# Epoch: 4 | Batch: 100 | Loss: 0.0211
# Epoch: 4 | Batch: 200 | Loss: 0.0327
# Epoch: 4 | Batch: 300 | Loss: 0.0179
# Epoch: 4 | Batch: 400 | Loss: 0.0573
# Epoch: 4 | Batch: 500 | Loss: 0.0288
# Epoch: 4 | Batch: 600 | Loss: 0.0227
# Epoch: 4 | Batch: 700 | Loss: 0.0206
# Epoch: 4 | Batch: 800 | Loss: 0.0381
# Epoch: 4 | Batch: 900 | Loss: 0.0890
# Epoch: 5 | Batch: 100 | Loss: 0.0053
# Epoch: 5 | Batch: 200 | Loss: 0.0306
# Epoch: 5 | Batch: 300 | Loss: 0.0682
# Epoch: 5 | Batch: 400 | Loss: 0.0108
# Epoch: 5 | Batch: 500 | Loss: 0.0119
# Epoch: 5 | Batch: 600 | Loss: 0.0137
# Epoch: 5 | Batch: 700 | Loss: 0.0207
# Epoch: 5 | Batch: 800 | Loss: 0.0132
# Epoch: 5 | Batch: 900 | Loss: 0.0520
# Epoch: 6 | Batch: 100 | Loss: 0.0115
# Epoch: 6 | Batch: 200 | Loss: 0.0277
# Epoch: 6 | Batch: 300 | Loss: 0.1136
# Epoch: 6 | Batch: 400 | Loss: 0.0061
# Epoch: 6 | Batch: 500 | Loss: 0.0572
# Epoch: 6 | Batch: 600 | Loss: 0.0020
# Epoch: 6 | Batch: 700 | Loss: 0.0043
# Epoch: 6 | Batch: 800 | Loss: 0.0511
# Epoch: 6 | Batch: 900 | Loss: 0.0058
# Epoch: 7 | Batch: 100 | Loss: 0.0349
# Epoch: 7 | Batch: 200 | Loss: 0.0079
# Epoch: 7 | Batch: 300 | Loss: 0.0140
# Epoch: 7 | Batch: 400 | Loss: 0.0058
# Epoch: 7 | Batch: 500 | Loss: 0.0208
# Epoch: 7 | Batch: 600 | Loss: 0.0250
# Epoch: 7 | Batch: 700 | Loss: 0.0203
# Epoch: 7 | Batch: 800 | Loss: 0.0031
# Epoch: 7 | Batch: 900 | Loss: 0.0191
# Epoch: 8 | Batch: 100 | Loss: 0.0027
# Epoch: 8 | Batch: 200 | Loss: 0.0110
# Epoch: 8 | Batch: 300 | Loss: 0.0008
# Epoch: 8 | Batch: 400 | Loss: 0.0057
# Epoch: 8 | Batch: 500 | Loss: 0.0009
# Epoch: 8 | Batch: 600 | Loss: 0.0039
# Epoch: 8 | Batch: 700 | Loss: 0.0018
# Epoch: 8 | Batch: 800 | Loss: 0.0016
# Epoch: 8 | Batch: 900 | Loss: 0.0001
# Epoch: 9 | Batch: 100 | Loss: 0.0766
# Epoch: 9 | Batch: 200 | Loss: 0.0011
# Epoch: 9 | Batch: 300 | Loss: 0.0012
# Epoch: 9 | Batch: 400 | Loss: 0.0047
# Epoch: 9 | Batch: 500 | Loss: 0.0092
# Epoch: 9 | Batch: 600 | Loss: 0.0176
# Epoch: 9 | Batch: 700 | Loss: 0.0015
# Epoch: 9 | Batch: 800 | Loss: 0.0026
# Epoch: 9 | Batch: 900 | Loss: 0.0044
# 33.62125539779663
# Training completed.
