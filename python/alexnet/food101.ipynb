# %%
from os.path import split

import torch
import numpy as np
import torchvision
import torch.nn as nn
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import time

# %%
transform = torchvision.transforms.Compose([
    torchvision.transforms.Resize((227, 227)),  # Resize images to 32x32 pixels
    torchvision.transforms.ToTensor(),        # Convert images to PyTorch tensors
    torchvision.transforms.Normalize(mean=(0.5,), std=(0.5,))  # Normalize with mean=0.5, std=0.5
])

train_dataset = torchvision.datasets.Food101(
    root='/home/kami/Documents/datasets/',
    split='train',
    download=False,
    transform=transform
)

train_loader = torch.utils.data.DataLoader(
    train_dataset,
    batch_size=64,
    shuffle=True
)


a = 0
for images, labels in train_loader:
    print(f"Batch shape: {images.shape}")  # Should be [64, 1, 32, 32] (batch, channels, height, width)
    print(f"Labels shape: {labels.shape}")  # Should be [64]
    print(f"Image tensor min: {images.min()}, max: {images.max()}")  # Check normalization
    break  # Only print the first batch

print(a)
# Out:
# Batch shape: torch.Size([64, 3, 227, 227])
# Labels shape: torch.Size([64])
# Image tensor min: -1.0, max: 1.0
# 0

# %%
class AlexNet(nn.Module):
    def __init__(self, num_classes=10, in_channels=1):
        super(AlexNet, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(in_channels, 96, kernel_size=11, stride=4, padding=0),
            nn.BatchNorm2d(96),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 3, stride = 2))
        self.layer2 = nn.Sequential(
            nn.Conv2d(96, 256, kernel_size=5, stride=1, padding=2),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 3, stride = 2))
        self.layer3 = nn.Sequential(
            nn.Conv2d(256, 384, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(384),
            nn.ReLU())
        self.layer4 = nn.Sequential(
            nn.Conv2d(384, 384, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(384),
            nn.ReLU())
        self.layer5 = nn.Sequential(
            nn.Conv2d(384, 256, kernel_size=3, stride=1, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size = 3, stride = 2))
        self.fc = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(9216, 4096),
            nn.ReLU())
        self.fc1 = nn.Sequential(
            nn.Dropout(0.5),
            nn.Linear(4096, 4096),
            nn.ReLU())
        self.fc2= nn.Sequential(
            nn.Linear(4096, num_classes))

    def forward(self, x):
        # print("size 01:" , x.shape)
        out = self.layer1(x)
        # print("size 02:" , out.shape)
        out = self.layer2(out)
        # print("size 03:" , out.shape)
        out = self.layer3(out)
        # print("size 04:" , out.shape)
        out = self.layer4(out)
        # print("size 05:" , out.shape)
        out = self.layer5(out)
        # print("size 06:" , out.shape)
        out = out.reshape(out.size(0), -1)
        # print("size 07:" , out.shape)
        out = self.fc(out)
        # print("size 08:" , out.shape)
        out = self.fc1(out)
        out = self.fc2(out)
        return out

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# device = torch.device('cpu')
model = AlexNet(num_classes=101,in_channels=3).to(device)
criterion = nn.CrossEntropyLoss()  # Combines log softmax and NLL loss
optimizer = optim.Adam(model.parameters(), lr=1e-3)  # Adam with learning rate 1e-3

st = time.time()
# Train for 10 epochs
model.train()
for epoch in range(10):
    batch_index = 0
    for images, labels in train_loader:
        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()

        outputs = model(images)
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        batch_index += 1
        if batch_index % 100 == 0:
            print(f"Epoch: {epoch} | Batch: {batch_index} | Loss: {loss.item():.4f}")

et = time.time()
print(et-st)
print("Training completed.")
# Out:
# cuda
# Epoch: 0 | Batch: 100 | Loss: 4.6022
# Epoch: 0 | Batch: 200 | Loss: 4.6126
# Epoch: 0 | Batch: 300 | Loss: 4.6163
# Epoch: 0 | Batch: 400 | Loss: 4.6155
# Epoch: 0 | Batch: 500 | Loss: 4.6173
# Epoch: 0 | Batch: 600 | Loss: 4.6142
# Epoch: 0 | Batch: 700 | Loss: 4.5971
# Epoch: 0 | Batch: 800 | Loss: 4.6063
# Epoch: 0 | Batch: 900 | Loss: 4.6094
# Epoch: 0 | Batch: 1000 | Loss: 4.5250
# Epoch: 0 | Batch: 1100 | Loss: 4.6236
# Epoch: 1 | Batch: 100 | Loss: 4.6466
# Epoch: 1 | Batch: 200 | Loss: 4.4977
# Epoch: 1 | Batch: 300 | Loss: 4.5809
# Epoch: 1 | Batch: 400 | Loss: 4.4827
# Epoch: 1 | Batch: 500 | Loss: 4.6126
# Epoch: 1 | Batch: 600 | Loss: 4.5365
# Epoch: 1 | Batch: 700 | Loss: 4.5984
# Epoch: 1 | Batch: 800 | Loss: 4.5866
# Epoch: 1 | Batch: 900 | Loss: 4.5352
# Epoch: 1 | Batch: 1000 | Loss: 4.5425
# Epoch: 1 | Batch: 1100 | Loss: 4.5833
# Epoch: 2 | Batch: 100 | Loss: 4.5369
# Epoch: 2 | Batch: 200 | Loss: 4.5461
# Epoch: 2 | Batch: 300 | Loss: 4.4850
# Epoch: 2 | Batch: 400 | Loss: 4.5143
# Epoch: 2 | Batch: 500 | Loss: 4.4825
# Epoch: 2 | Batch: 600 | Loss: 4.5901
# Epoch: 2 | Batch: 700 | Loss: 4.5339
# Epoch: 2 | Batch: 800 | Loss: 4.5435
# Epoch: 2 | Batch: 900 | Loss: 4.5106
# Epoch: 2 | Batch: 1000 | Loss: 4.5764
# Epoch: 2 | Batch: 1100 | Loss: 4.5355
# Epoch: 3 | Batch: 100 | Loss: 4.6037
# Epoch: 3 | Batch: 200 | Loss: 4.5146
# Epoch: 3 | Batch: 300 | Loss: 4.5176
# Epoch: 3 | Batch: 400 | Loss: 4.5358
# Epoch: 3 | Batch: 500 | Loss: 4.5714
# Epoch: 3 | Batch: 600 | Loss: 4.4832
# Epoch: 3 | Batch: 700 | Loss: 4.4773
# Epoch: 3 | Batch: 800 | Loss: 4.5548
# Epoch: 3 | Batch: 900 | Loss: 4.5107
# Epoch: 3 | Batch: 1000 | Loss: 4.5069
# Epoch: 3 | Batch: 1100 | Loss: 4.4719
# Epoch: 4 | Batch: 100 | Loss: 4.4697
# Epoch: 4 | Batch: 200 | Loss: 4.5755
# Epoch: 4 | Batch: 300 | Loss: 4.5861
# Epoch: 4 | Batch: 400 | Loss: 4.4877
# Epoch: 4 | Batch: 500 | Loss: 4.4902
# Epoch: 4 | Batch: 600 | Loss: 4.5296
# Epoch: 4 | Batch: 700 | Loss: 4.4380
# Epoch: 4 | Batch: 800 | Loss: 4.5546
# Epoch: 4 | Batch: 900 | Loss: 4.5859
# Epoch: 4 | Batch: 1000 | Loss: 4.5014
# Epoch: 4 | Batch: 1100 | Loss: 4.6640
# Epoch: 5 | Batch: 100 | Loss: 4.5993
# Epoch: 5 | Batch: 200 | Loss: 4.6290
# Epoch: 5 | Batch: 300 | Loss: 4.4283
# Epoch: 5 | Batch: 400 | Loss: 4.4231
# Epoch: 5 | Batch: 500 | Loss: 4.4303
# Epoch: 5 | Batch: 600 | Loss: 4.4863
# Epoch: 5 | Batch: 700 | Loss: 4.5250
# Epoch: 5 | Batch: 800 | Loss: 4.5007
# Epoch: 5 | Batch: 900 | Loss: 4.5681
# Epoch: 5 | Batch: 1000 | Loss: 4.4929
# Epoch: 5 | Batch: 1100 | Loss: 4.4680
# Epoch: 6 | Batch: 100 | Loss: 4.5108
# Epoch: 6 | Batch: 200 | Loss: 4.5895
# Epoch: 6 | Batch: 300 | Loss: 4.4591
# Epoch: 6 | Batch: 400 | Loss: 4.4732
# Epoch: 6 | Batch: 500 | Loss: 4.4764
# Epoch: 6 | Batch: 600 | Loss: 4.6297
# Epoch: 6 | Batch: 700 | Loss: 4.4615
# Epoch: 6 | Batch: 800 | Loss: 4.5260
# Epoch: 6 | Batch: 900 | Loss: 4.5203
# Epoch: 6 | Batch: 1000 | Loss: 4.5893
# Epoch: 6 | Batch: 1100 | Loss: 4.5067
# Epoch: 7 | Batch: 100 | Loss: 4.4978
# Epoch: 7 | Batch: 200 | Loss: 4.4805
# Epoch: 7 | Batch: 300 | Loss: 4.4845
# Epoch: 7 | Batch: 400 | Loss: 4.5076
# Epoch: 7 | Batch: 500 | Loss: 4.5132
# Epoch: 7 | Batch: 600 | Loss: 4.4635
# Epoch: 7 | Batch: 700 | Loss: 4.5195
# Epoch: 7 | Batch: 800 | Loss: 4.4334
# Epoch: 7 | Batch: 900 | Loss: 4.5280
# Epoch: 7 | Batch: 1000 | Loss: 4.4523
# Epoch: 7 | Batch: 1100 | Loss: 4.4082
# Epoch: 8 | Batch: 100 | Loss: 4.4979
# Epoch: 8 | Batch: 200 | Loss: 4.6317
# Epoch: 8 | Batch: 300 | Loss: 4.4788
# Epoch: 8 | Batch: 400 | Loss: 4.4507
# Epoch: 8 | Batch: 500 | Loss: 4.4664
# Epoch: 8 | Batch: 600 | Loss: 4.5042
# Epoch: 8 | Batch: 700 | Loss: 4.4717
# Epoch: 8 | Batch: 800 | Loss: 4.4284
# Epoch: 8 | Batch: 900 | Loss: 4.4969
# Epoch: 8 | Batch: 1000 | Loss: 4.5473
# Epoch: 8 | Batch: 1100 | Loss: 4.6086
# Epoch: 9 | Batch: 100 | Loss: 4.3984
# Epoch: 9 | Batch: 200 | Loss: 4.5330
# Epoch: 9 | Batch: 300 | Loss: 4.4450
# Epoch: 9 | Batch: 400 | Loss: 4.5591
# Epoch: 9 | Batch: 500 | Loss: 4.4259
# Epoch: 9 | Batch: 600 | Loss: 4.4533
# Epoch: 9 | Batch: 700 | Loss: 4.6325
# Epoch: 9 | Batch: 800 | Loss: 4.4024
# Epoch: 9 | Batch: 900 | Loss: 4.5597
# Epoch: 9 | Batch: 1000 | Loss: 4.4267
# Epoch: 9 | Batch: 1100 | Loss: 4.4074
# 1584.0521092414856
# Training completed.
